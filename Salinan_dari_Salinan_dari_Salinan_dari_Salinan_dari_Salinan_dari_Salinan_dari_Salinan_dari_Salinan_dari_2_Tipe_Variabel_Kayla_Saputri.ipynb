# %% [markdown]
# <a href="https://colab.research.google.com/github/kayla-sa/KKA-X-Semester-1-Kayla-S/blob/main/Salinan_dari_Salinan_dari_Salinan_dari_Salinan_dari_Salinan_dari_Salinan_dari_Salinan_dari_Salinan_dari_2_Tipe_Variabel_Kayla_Saputri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar Varia

# %%
print("kaylasaputrii.2025@gmail.com")
print("kaylasaputrii.2025@gmail.com")
print("kaylasaputrii.2025@gmail.com")
# Out:
# kaylasaputrii.2025@gmail.com
# kaylasaputrii.2025@gmail.com
# kaylasaputrii.2025@gmail.com

# %%
email_user_1 ="kaylasaputrii.2025@gmail.com"
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# kaylasaputrii.2025@gmail.com
# kaylasaputrii.2025@gmail.com
# kaylasaputrii.2025@gmail.com

# %% [markdown]
# Peraturan Penulisan Variabel

# %%
#sensitif terhadap kapital
emil_user_2 ="keenan Akbar"
print(Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2597203354.py in <cell line: 0>()
#       1 #sensitif terhadap kapital
#       2 emil_user_2 ="keenan Akbar"
# ----> 3 print(Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "Keenan Akbar"
print(email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2= "Yoga Akbar"
print(emailuser2)
# Out:
# Yoga Akbar

# %%
#hanya boleh menggunakan angka, huruf,underscore
email user 3 = "Dimas Esa"
print(email user 3)
# Out:
#   File "/tmp/ipython-input-4035977725.py", line 2
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser3 = "Dimas Esa"
print(emailuser3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4005998793.py in <cell line: 0>()
#       1 emailuser3 = "Dimas Esa"
# ----> 2 print(emailuser3)
#
# TypeError: 'str' object is not callable

# %%
#Tidak boleh di dahului oleh angka
4_email_user = "hanafi Naufal"
print(4_email_user)
# Out:
#   File "/tmp/ipython-input-2777469549.py", line 2
#     4_email_user = "hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
for = "Naufal Fajri"
print(for)
# Out:
#   File "/tmp/ipython-input-3217420691.py", line 2
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"
print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3121028777.py in <cell line: 0>()
#       1 print = "Alif Nadya"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"
print(Print)
# Out:
# Alif Nadya

# %%
_ = "Azka Alifta"

# %%
print(_)
# Out:
# Azka Alifta

# %%
_ = " Kenzo Aliando"

# %%
print (_)
# Out:
#  Kenzo Aliando

# %% [markdown]
# #TUGAS

# %%
Nama = "Ahmad Fauzi"
Kelas = "x,12"
Hobi = "membaca"
print(Nama,Kelas,Hobi)
# Out:
# Ahmad Fauzi x,12 membaca

# %% [markdown]
# #Assignment

# %%
#single assignment
beratbadansiswa1 = 90
print(beratbadansiswa1)
# Out:
# 90

# %%
#multiple assignment
nilai_kka_dias,nilai_kka_azka =99,98
print(nilai_kka_dias)
print(nilai_kka_azka)
# Out:
# 99
# 98

# %%
nilai_kka_dias, nilai_kka_azka = 99,98,70
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-21296680.py in <cell line: 0>()
# ----> 1 nilai_kka_dias, nilai_kka_azka = 99,98,70
#
# ValueError: too many values to unpack (expected 2)

# %%
usia_anwar = usia_sahda = 20
print(usia_anwar)
print(usia_sahda)
# Out:
# 20
# 20

# %% [markdown]
# #Latihan Soal

# %%
namasiswa1 ="Andi"
print(namasiswa1)
# Out:
# Andi

# %%
nama = "Budi"
umur =15
kelas= "9a"

print(nama)
print(umur)
print(kelas)
# Out:
# Budi
# 15
# 9a

# %%
berat_andi = 45.5
berat_siti =45.5
berat_eko =45.5
print(berat_andi,berat_siti,berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #Operator dalam python

# %%
#Tanpa variabel
print(2+8)
# Out:
# 10

# %%
#operasi di simpan ke variabel
kelereng_dias = 2
kelereng_azka = 8
print(kelereng_dias+kelereng_azka)
# Out:
# 10

# %%
#hasil operasi disimpan ke variabel
total_kelereng = 8+2
print(total_kelereng)
# Out:
# 10

# %%
#operasi dan hasil operasi disimpan ke variabel
kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng_azka+kelereng_dias
print(total_kelereng)
# Out:
# 10

# %% [markdown]
# #Latihan soal

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol =24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Jenis Tipe Variabel

# %%
a = "Handayani"
print(a)
type(a)
# Out:
# Handayani
# str

# %%
b = -0.001
print(b)
type(b)
# Out:
# -0.001
# float

# %%
c = -50
print(c)
type(c)
# Out:
# -50
# int

# %%
d =True
print(d)
type(d)
# Out:
# True
# bool

# %%
d =true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-530750476.py in <cell line: 0>()
# ----> 1 d =true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
e =1,89
print(e)
type(e)
# Out:
# (1, 89)
# tuple

# %%
x = "False"
print(x)
type(x)
# Out:
# False
# str

# %%
type(-500)
# Out:
# int

# %%
k = float(88)
print(k)
type(k)
# Out:
# 88.0
# float

# %%
z =float(-100)
print(z)
type(z)
# Out:
# -100.0
# float

# %% [markdown]
# #Perubahan Tipe Variabel

# %%
f =8.9
print(f)
type(f)
# Out:
# 8.9
# float

# %%
f =int(f)
print(f)
type(f)
# Out:
# 8
# int

# %%
g =-2.05
print(g)
type(g)
# Out:
# -2.05
# float

# %%
g =int(g)
print(g)
type(g)
# Out:
# -2
# int

# %%
g =bool(g)
print(g)
type(g)
# Out:
# True
# bool

# %%
h =True
print(h)
type(h)
# Out:
# True
# bool

# %%
h =int(h)
print(h)
type(h)
# Out:
# 1
# int

# %% [markdown]
# #Operator perbandingan dan Operator logika

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5>10 or 5<=10))
# Out:
# False

# %% [markdown]
# #soal

# %%
tinggi_nino = 170
berat_nino = 55
umur_nino = 23

tinggi_minimal = 165
berat_minimal = 50
umur_maksimal = 25

print((tinggi_nino >= tinggi_minimal) and (berat_nino >= berat_minimal) and (umur_nino <= umur_maksimal))
# Out:
# True
