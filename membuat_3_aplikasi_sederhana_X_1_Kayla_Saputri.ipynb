# %% [markdown]
# <a href="https://colab.research.google.com/github/kayla-sa/KKA-X-Semester-1-Kayla-S/blob/main/membuat_3_aplikasi_sederhana_X_1_Kayla_Saputri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
print("halo anwar")
# Out:
# halo anwar

# %%
panjang =int(input("masukan panjang dari persegi panjang (cm):"))
lebar =int(input("masukan lebar dari persegi panjang (cm):"))

luas = panjang * lebar

print(f"\nLuas dari persegi panjangnya adalah {luas} cm^2.")
# Out:
# masukan panjang dari persegi panjang (cm):5
# masukan lebar dari persegi panjang (cm):4
#
# Luas dari persegi panjangnya adalah 20 cm^2.

# %% [markdown]
# #Nama kelompok:Burok keren
#
# Nama: Kayla Saputri
#
# Kelas: X.1
#
# Nomor absen:15

# %%
Tinggi = int(input("Masukan tinggi dari tabung (cm): "))
JariJari =int(input("Masukan jarijari dari tabung (cm): "))
Phi = 22/7

Volume = Phi*JariJari**2*Tinggi

print(f"\nVolume dari tabung adalah {Volume} cm^3.")
# Out:
# Masukan tinggi dari tabung (cm): 14
# Masukan jarijari dari tabung (cm): 7
#
# Volume dari tabung adalah 2156.0 cm^3.
